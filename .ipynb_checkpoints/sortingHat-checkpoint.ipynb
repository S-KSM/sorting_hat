# %%
import pandas as pd

# %%
data = pd.read_excel("./data/70251 113R1.xlsx",sheetname="ps-4")

# %%
data = data.reset_index()[["Select","ID","Name","Program and Plan", "Level"]]

# %%
data["Level"].unique()
# Out:
# array(['Junior', 'Freshman', 'Sophomore', 'Senior'], dtype=object)

# %%
len(data["Program and Plan"].unique())
# Out:
# 21

# %%
data.shape
# Out:
# (72, 5)

# %%
f_count = data[data["Select"]=="f"].shape[0]

# %%
groups = {}

# %%
f_count //12
# Out:
# 2

# %%
(data.shape[0]-f_count)//12
# Out:
# 3

# %%
class member:
    def __init__(self,name,ID,plan,level,sex):
        self.name = name
        self.ID = ID
        self.plan = plan
        self.level = level
        self.sex = sex
        
        
class groups(member):
    def __init__(self):
        self.number = 0
        self.member = []
        
    def len(self):
        return self.number
    def add_member(self,mymember):
        self.member.append(mymember.name)
        self.number += 1
        self.

# %%
data
# Out:
#    Select          ID                                      Name  \
# 0       m  1204046761                       Clark,Evan Johannes
# 1       m  1209164563                         Hauck,Chad Steven
# 2       f  1208926715                        Phillips,Emily Ann
# 3       f  1209348227            Schneider-Utaka,Aika Kunigunda
# 4       m  1209115176                      Titherington,Michael
# 5       f  1209767283           Valverde-Vesling,Valeria Andrea
# 6       m  1208904862                                Aziz,Ramon
# 7       m  1209876262                     Moore,Charles Brandon
# 8       f  1208601910                       Moss,Sumher Jaziman
# 9       f  1209471052                  Scott,Cydni Anya Kealani
# 10      m  1209296968                      Shields,Douglas Alan
# 11      f  1208083834                                Wiley,Erin
# 12      m  1208328858         Amiri,Salman Abdulla Mir Muttaleb
# 13      f  1209191200                        Begay,Elyssa Amber
# ...
